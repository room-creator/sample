# %% [markdown]
# <a href="https://colab.research.google.com/github/room-creator/sample/blob/main/resources/inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install piano_transcription_inference

# %%
# !apt install ffmpeg wget
# !pip uninstall librosa numpy -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1.1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Found existing installation: librosa 0.8.1
# Uninstalling librosa-0.8.1:
#   Successfully uninstalled librosa-0.8.1
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2

# %%
# !pip install piano_transcription_inference
# Out:
# Requirement already satisfied: piano_transcription_inference in /usr/local/lib/python3.12/dist-packages (0.0.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from piano_transcription_inference) (3.10.0)
# Requirement already satisfied: mido in /usr/local/lib/python3.12/dist-packages (from piano_transcription_inference) (1.3.3)
# Collecting librosa (from piano_transcription_inference)
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: torchlibrosa in /usr/local/lib/python3.12/dist-packages (from piano_transcription_inference) (0.1.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (0.60.0)
# Collecting numpy>=1.22.3 (from librosa->piano_transcription_inference)
#   Using cached numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->piano_transcription_inference) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa->piano_transcription_inference) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->piano_transcription_inference) (0.43.0)
#   Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->piano_transcription_inference) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->piano_transcription_inference) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->piano_transcription_inference) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->piano_transcription_inference) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->piano_transcription_inference) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->piano_transcription_inference) (2025.10.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->piano_transcription_inference) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa->piano_transcription_inference) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->piano_transcription_inference) (2.23)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->piano_transcription_inference) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->piano_transcription_inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->piano_transcription_inference) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->piano_transcription_inference) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->piano_transcription_inference) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->piano_transcription_inference) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->piano_transcription_inference) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->piano_transcription_inference) (1.17.0)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# Installing collected packages: numpy, librosa
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [librosa]
# Successfully installed librosa-0.11.0 numpy-2.0.2

# %%
from IPython.display import Audio

# %% [markdown]
# # Transcribe using code

# %%
import numpy as np
import os
import librosa
import audioread

def load_audio(path, sr=22050, mono=True, offset=0.0, duration=None,
    dtype=np.float32, res_type='kaiser_best',
    backends=[audioread.ffdec.FFmpegAudioFile]):
    """Load audio. Copied from librosa.core.load() except that ffmpeg backend is
    always used in this function."""

    y = []
    with audioread.audio_open(os.path.realpath(path), backends=backends) as input_file:
        sr_native = input_file.samplerate
        n_channels = input_file.channels

        s_start = int(np.round(sr_native * offset)) * n_channels

        if duration is None:
            s_end = np.inf
        else:
            s_end = s_start + (int(np.round(sr_native * duration))
                               * n_channels)

        n = 0

        for frame in input_file:
            # Modified to use librosa.util.buf_to_float
            frame = librosa.util.buf_to_float(frame, dtype=dtype)
            n_prev = n
            n = n + len(frame)

            if n < s_start:
                # offset is after the current frame
                # keep reading
                continue

            if s_end < n_prev:
                # we're off the end.  stop reading
                break

            if s_end < n:
                # the end is in this frame.  crop.
                frame = frame[:s_end - n_prev]

            if n_prev <= s_start <= n:
                # beginning is in this frame
                frame = frame[(s_start - n_prev):]

            # tack on the current frame
            y.append(frame)

    if y:
        y = np.concatenate(y)

        if n_channels > 1:
            y = y.reshape((-1, n_channels)).T
            if mono:
                y = librosa.to_mono(y)

        if sr is not None:
            y = librosa.resample(y, orig_sr=sr_native, target_sr=sr, res_type=res_type)

        else:
            sr = sr_native

    # Final cleanup for dtype and contiguity
    y = np.ascontiguousarray(y, dtype=dtype)

    return (y, sr)

# %%
from piano_transcription_inference import PianoTranscription, sample_rate

def transcribe(audio_path, output_midi_path):
    # Load audio
    audio, _ = load_audio(audio_path, sr=sample_rate, mono=True)

    # Transcriptor
    transcriptor = PianoTranscription(device='cpu', checkpoint_path=None)

    # Transcribe and write out to MIDI file
    transcriptor.transcribe(audio, output_midi_path)

# %%
# !wget https://github.com/qiuqiangkong/piano_transcription_inference/raw/master/resources/cut_liszt.mp3
# Out:
# --2025-11-15 02:52:15--  https://github.com/qiuqiangkong/piano_transcription_inference/raw/master/resources/cut_liszt.mp3
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/qiuqiangkong/piano_transcription_inference/master/resources/cut_liszt.mp3 [following]
# --2025-11-15 02:52:16--  https://raw.githubusercontent.com/qiuqiangkong/piano_transcription_inference/master/resources/cut_liszt.mp3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240633 (235K) [audio/mpeg]
# Saving to: ‘cut_liszt.mp3.2’
#
# cut_liszt.mp3.2     100%[===================>] 234.99K  --.-KB/s    in 0.004s
#
# 2025-11-15 02:52:16 (60.0 MB/s) - ‘cut_liszt.mp3.2’ saved [240633/240633]

# %%
# Audio('05_緑の昼下がり.aif', rate=sample_rate)

# %%
transcribe('05_緑の昼下がり.aif', '05_緑の昼下がり.mid')
# Out:
# Checkpoint path: /root/piano_transcription_inference_data/note_F1=0.9677_pedal_F1=0.9186.pth
# Total size: ~165 MB
# Using cuda for inference.
# GPU number: 1
# Segment 0 / 33
# Segment 1 / 33
# Segment 2 / 33
# Segment 3 / 33
# Segment 4 / 33
# Segment 5 / 33
# Segment 6 / 33
# Segment 7 / 33
# Segment 8 / 33
# Segment 9 / 33
# Segment 10 / 33
# Segment 11 / 33
# Segment 12 / 33
# Segment 13 / 33
# Segment 14 / 33
# Segment 15 / 33
# Segment 16 / 33
# Segment 17 / 33
# Segment 18 / 33
# Segment 19 / 33
# Segment 20 / 33
# Segment 21 / 33
# Segment 22 / 33
# Segment 23 / 33
# Segment 24 / 33
# Segment 25 / 33
# Segment 26 / 33
# Segment 27 / 33
# Segment 28 / 33
# Segment 29 / 33
# Segment 30 / 33
# Segment 31 / 33
# Segment 32 / 33
# Segment 33 / 33
# Write out to 05_緑の昼下がり.mid

# %% [markdown]
# # Render midi plot

# %%
# !apt install git

# %%
# !git clone https://github.com/bytedance/piano_transcription.git

# %%
pip install -r piano_transcription/requirements.txt

# %%
# !mkdir results

# %%
import sys
sys.path.append('piano_transcription/utils')
sys.path.append('piano_transcription/pytorch')
from collections import namedtuple

plot_args = namedtuple('PlotArgs', ['audio_path', 'midi_path'])

from plot_for_paper import plot_midi
plot_midi(plot_args('cut_liszt.mp3', 'cut_liszt.mid'))
